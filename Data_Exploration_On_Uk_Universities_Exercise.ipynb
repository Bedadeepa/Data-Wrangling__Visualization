# %% [markdown]
# <a href="https://colab.research.google.com/github/Bedadeepa/MachineLearning/blob/main/Data_Exploration_On_Uk_Universities_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Firstly we have to mount the Google drive because we need the Data set which is present inside it.**

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'
# Out:
# Hello Google Drive!

# %% [markdown]
# **Like this we can mention the path of the data set which we have to explore.**

# %%
path="/gdrive/MyDrive/Colab_data_file/uk_univercities/archive.zip"

# %% [markdown]
# #Call Libraries
#  **Let's invite the party people here because without them our exploratin party is impossible**

# %%
# 1.0 Call libraries
# %reset -f      # clear all variables preveously created #magic commands
# 1.1 For data manipulations
import numpy as np
import pandas as pd
from numpy.random import default_rng

# 1.2 For plotting
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl     # For creating colormaps

# 1.3 For data processing
from sklearn.preprocessing import StandardScaler

# 1.4 OS related
import os

# 1.5 for working in ipython
#%matplotlib qt5
#%matplotlib inline
# Out:
# Don't know how to reset  #, please run `%reset?` for details
# Don't know how to reset  clear, please run `%reset?` for details
# Don't know how to reset  all, please run `%reset?` for details
# Don't know how to reset  variables, please run `%reset?` for details
# Don't know how to reset  preveously, please run `%reset?` for details
# Don't know how to reset  created, please run `%reset?` for details
# Don't know how to reset  #magic, please run `%reset?` for details
# Don't know how to reset  commands, please run `%reset?` for details

# %%
#1.6 From a cell display outputs from multiple commands:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# 1.6.1 For generating random numbers:
rng = default_rng()

# %% [markdown]
# **First and foremost it is important to have a look at data to get a clear sense on what we work on.**

# %% [markdown]
# # Read Data
# ###Load datasets for demonstrations

# %%
universities = pd. read_csv(path)

# %% [markdown]
# # Peek Data,Setting the context

# %% [markdown]
# Let's get an idea ab at the data using following pandas functions.
#
#
# ---
#
# *  DataFrame.head()
# *   DataFrame.tail()
# *   DataFrame.shape
# *  DataFrame.columns

# %% [markdown]
#  **How can we get the first 5 rows of the data set???**

# %%
universities.head()
# Out:
#             University_name              Region  Founded_year  \
# 0   University of Cambridge     East of England          1209
# 1      University of Oxford  South East England          1096
# 2  University of St Andrews            Scotland          1413
# 3   Imperial College London              London          1907
# 4   Loughborough University       East Midlands          1966
#
#                                                Motto  UK_rank  World_rank  \
# 0               From here, light and sacred draughts        1           4
# 1                               The Lord is my light        2           2
# 2                                      Ever to excel        3          86
# 3  Knowledge is the adornment and safeguard of th...        4           8
# 4                   With Truth, Knowledge and Labour        5         404
#
#    CWUR_score  Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0        94.1                  6.5                        21750
# ...

# %% [markdown]
# **How can we get the first 15  rows of the data set???**

# %%
universities.head(15)
# Out:
#                                      University_name  \
# 0                            University of Cambridge
# 1                               University of Oxford
# 2                           University of St Andrews
# 3                            Imperial College London
# 4                            Loughborough University
# 5   London School of Economics and Political Science
# 6                                  Durham University
# 7                               Lancaster University
# 8                          University College London
# 9                              University of Warwick
# 10                                University of Bath
# 11                              University of Exeter
# 12                               University of Leeds
# 13                          University of Birmingham
# 14                             University of Bristol
#
#                       Region  Founded_year  \
# 0            East of England          1209
# ...

# %% [markdown]
# **its about the first rows , can we get the last rows ???? let's find it out.....**

# %%
 
universities.tail()
# Out:
#                     University_name           Region  Founded_year  \
# 126       University of East London           London          1992
# 127      University of Bedfordshire  East of England          2006
# 128           University of Suffolk  East of England          2007
# 129      Wrexham Glyndwr University            Wales          2008
# 130  Ravensbourne University London           London          1962
#
#                                Motto  UK_rank  World_rank  CWUR_score  \
# 126  Science and fulfillment of vows      127         971         NaN
# 127                              NaN      128        1281         NaN
# 128            Honesty and diligence      129        4030         NaN
# 129     Confidence through Education      130        2397         NaN
# 130            Designed for industry      131        2759         NaN
#
#      Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 126                  4.5                        10700
# ...

# %% [markdown]
# **Wanna see more?. try -> univercities.tail(13) for last 13 rows.**

# %%
universities.tail(13)
# Out:
#                     University_name                    Region  Founded_year  \
# 118       University of Westminster                    London          1838
# 119        Anglia Ruskin University           East of England          1858
# 120           University of Cumbria        North West England          2007
# 121          University of Brighton        South East England          1992
# 122        Leeds Beckett University  Yorkshire and the Humber          1992
# 123     University of Wolverhampton             West Midlands          1992
# 124            University of Bolton        North West England          2004
# 125  London Metropolitan University                    London          1848
# 126       University of East London                    London          1992
# 127      University of Bedfordshire           East of England          2006
# 128           University of Suffolk           East of England          2007
# ...

# %% [markdown]
#  look here we don't know how many how many rows and columns are there in the data set
#
#
# lets try using **".shape "**once

# %%
 
universities.shape
# Out:
# (131, 21)

# %% [markdown]
# Oh!! We can see Our dataset  has 131  rows, 21 columns...

# %% [markdown]
# **let's check the column names in the data set!!!!**

# %%
universities.columns
# Out:
# Index(['University_name', 'Region', 'Founded_year', 'Motto', 'UK_rank',
#        'World_rank', 'CWUR_score', 'Minimum_IELTS_score',
#        'UG_average_fees_(in_pounds)', 'PG_average_fees_(in_pounds)',
#        'International_students', 'Student_satisfaction', 'Student_enrollment',
#        'Academic_staff', 'Control_type', 'Academic_Calender', 'Campus_setting',
#        'Estimated_cost_of_living_per_year_(in_pounds)', 'Latitude',
#        'Longitude', 'Website'],
#       dtype='object')

# %% [markdown]
# we can count them also using **len()**

# %%
len(universities.columns)
# Out:
# 21

# %% [markdown]
# # Exploration Of data

# %% [markdown]
# ###NaN value Idendification
# How to find out NaNs in the dataset????

# %%
universities.isnull()
# Out:
#      University_name  Region  Founded_year  Motto  UK_rank  World_rank  \
# 0              False   False         False  False    False       False
# 1              False   False         False  False    False       False
# 2              False   False         False  False    False       False
# 3              False   False         False  False    False       False
# 4              False   False         False  False    False       False
# ..               ...     ...           ...    ...      ...         ...
# 126            False   False         False  False    False       False
# 127            False   False         False   True    False       False
# 128            False   False         False  False    False       False
# 129            False   False         False  False    False       False
# 130            False   False         False  False    False       False
#
#      CWUR_score  Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# ...

# %% [markdown]
# <h4>Overall how many values are nulls</h4>

# %%
np.sum(universities.isnull()).sort_values(ascending = False)
# Out:
# CWUR_score                                       47
# Academic_Calender                                26
# Campus_setting                                   18
# Motto                                            17
# University_name                                   0
# Student_enrollment                                0
# Longitude                                         0
# Latitude                                          0
# Estimated_cost_of_living_per_year_(in_pounds)     0
# Control_type                                      0
# Academic_staff                                    0
# International_students                            0
# Student_satisfaction                              0
# Region                                            0
# PG_average_fees_(in_pounds)                       0
# UG_average_fees_(in_pounds)                       0
# Minimum_IELTS_score                               0
# World_rank                                        0
# ...

# %%
#Sum of all NaNs across row
universities.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 126    1
# 127    2
# 128    3
# 129    2
# 130    1
# Length: 131, dtype: int64

# %%
##Sum of all NaNs across column
universities.isnull().sum(axis=0)
# Out:
# University_name                                   0
# Region                                            0
# Founded_year                                      0
# Motto                                            17
# UK_rank                                           0
# World_rank                                        0
# CWUR_score                                       47
# Minimum_IELTS_score                               0
# UG_average_fees_(in_pounds)                       0
# PG_average_fees_(in_pounds)                       0
# International_students                            0
# Student_satisfaction                              0
# Student_enrollment                                0
# Academic_staff                                    0
# Control_type                                      0
# Academic_Calender                                26
# Campus_setting                                   18
# Estimated_cost_of_living_per_year_(in_pounds)     0
# ...

# %% [markdown]
# How to get **column wise mean**?????
#
# here is the answer...

# %%
universities[['UK_rank']].mean()
# Out:
# UK_rank    65.900763
# dtype: float64

# %%
universities['UK_rank'].mean()# Here if we remove a [] then it will show only the Mean not the Column name.
# Out:
# 65.90076335877863

# %%
# skip the NaN value and give the Mean 
universities.mean(skipna=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Founded_year                                      1925.221374
# UK_rank                                             65.900763
# World_rank                                        1097.595420
# CWUR_score                                          73.960714
# Minimum_IELTS_score                                  4.946565
# UG_average_fees_(in_pounds)                      12537.450382
# PG_average_fees_(in_pounds)                      13099.763359
# Estimated_cost_of_living_per_year_(in_pounds)     8644.732824
# Latitude                                            52.749708
# Longitude                                           -1.673287
# dtype: float64

# %%
# With  the NaN value and give the Mean 
universities.mean(skipna=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Founded_year                                      1925.221374
# UK_rank                                             65.900763
# World_rank                                        1097.595420
# CWUR_score                                                NaN
# Minimum_IELTS_score                                  4.946565
# UG_average_fees_(in_pounds)                      12537.450382
# PG_average_fees_(in_pounds)                      13099.763359
# Estimated_cost_of_living_per_year_(in_pounds)     8644.732824
# Latitude                                            52.749708
# Longitude                                           -1.673287
# dtype: float64

# %%
universities.head(10)
# Out:
#                                     University_name              Region  \
# 0                           University of Cambridge     East of England
# 1                              University of Oxford  South East England
# 2                          University of St Andrews            Scotland
# 3                           Imperial College London              London
# 4                           Loughborough University       East Midlands
# 5  London School of Economics and Political Science              London
# 6                                 Durham University  North East England
# 7                              Lancaster University  North West England
# 8                         University College London              London
# 9                             University of Warwick       West Midlands
#
#    Founded_year                                              Motto  UK_rank  \
# 0          1209               From here, light and sacred draughts        1
# ...

# %% [markdown]
# <b>Let's see the World wise rank and UK rank of the univercities:</b>

# %%
#Display 2 column of the dataset
universities[['University_name','UK_rank','World_rank']]
# Out:
#                     University_name  UK_rank  World_rank
# 0           University of Cambridge        1           4
# 1              University of Oxford        2           2
# 2          University of St Andrews        3          86
# 3           Imperial College London        4           8
# 4           Loughborough University        5         404
# ..                              ...      ...         ...
# 126       University of East London      127         971
# 127      University of Bedfordshire      128        1281
# 128           University of Suffolk      129        4030
# 129      Wrexham Glyndwr University      130        2397
# 130  Ravensbourne University London      131        2759
#
# [131 rows x 3 columns]

# %%
type(universities[['World_rank']])#this is a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
universities[['World_rank']]
# Out:
#      World_rank
# 0             4
# 1             2
# 2            86
# 3             8
# 4           404
# ..          ...
# 126         971
# 127        1281
# 128        4030
# 129        2397
# 130        2759
#
# [131 rows x 1 columns]

# %%
type(universities['World_rank'])#this is a Series
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### We can Use iloc/loc to Display the Perticular data

# %% [markdown]
# <h4>Display the data between Line 5 and 10 </h4>

# %%
universities.iloc[5:11]  #Access by Position
# Out:
#                                      University_name              Region  \
# 5   London School of Economics and Political Science              London
# 6                                  Durham University  North East England
# 7                               Lancaster University  North West England
# 8                          University College London              London
# 9                              University of Warwick       West Midlands
# 10                                University of Bath  South West England
#
#     Founded_year                                            Motto  UK_rank  \
# 5           1895                     To know the causes of things        6
# 6           1832          Her foundations are upon the holy hills        7
# 7           1964                           Truth lies open to all        8
# 8           1826    Let all come who by merit most deserve reward        9
# 9           1965                                Mind Moves matter       10
# ...

# %%
universities.loc[[7,4,15]]#Access by index-name
# Out:
#             University_name              Region  Founded_year  \
# 7      Lancaster University  North West England          1964
# 4   Loughborough University       East Midlands          1966
# 15    University of Glasgow            Scotland          1451
#
#                                Motto  UK_rank  World_rank  CWUR_score  \
# 7             Truth lies open to all        8         130        76.1
# 4   With Truth, Knowledge and Labour        5         404        72.8
# 15   The Way, the Truth and the Life       16          76        80.7
#
#     Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 7                   5.5                        14940
# 4                   5.5                        16400
# 15                  5.5                        14500
#
#     PG_average_fees_(in_pounds)  ... Student_satisfaction Student_enrollment  \
# 7                         14200  ...               79.30%      10,000-14,999
# ...

# %%
universities.describe()
# Out:
#        Founded_year     UK_rank  World_rank  CWUR_score  Minimum_IELTS_score  \
# count    131.000000  131.000000   131.00000   84.000000           131.000000
# mean    1925.221374   65.900763  1097.59542   73.960714             4.946565
# std      139.040187   37.922158  1145.00106    6.351473             0.617850
# min     1096.000000    1.000000     2.00000   65.900000             4.000000
# 25%     1896.000000   33.500000   196.00000   68.675000             4.500000
# 50%     1966.000000   65.000000   691.00000   72.600000             4.500000
# 75%     1992.000000   98.000000  1569.00000   77.700000             5.500000
# max     2013.000000  131.000000  5253.00000   94.100000             6.500000
#
#        UG_average_fees_(in_pounds)  PG_average_fees_(in_pounds)  \
# count                   131.000000                   131.000000
# mean                  12537.450382                 13099.763359
# std                    2555.318861                  3106.398149
# ...

# %% [markdown]
#  Thats some valueble info we got from only one line of code!.

# %%
# Check data types of attributes
#

# %%
universities.dtypes
# Out:
# University_name                                   object
# Region                                            object
# Founded_year                                       int64
# Motto                                             object
# UK_rank                                            int64
# World_rank                                         int64
# CWUR_score                                       float64
# Minimum_IELTS_score                              float64
# UG_average_fees_(in_pounds)                        int64
# PG_average_fees_(in_pounds)                        int64
# International_students                            object
# Student_satisfaction                              object
# Student_enrollment                                object
# Academic_staff                                    object
# Control_type                                      object
# Academic_Calender                                 object
# ...

# %%
universities.head(3)
universities.info()               # Also informs how much memory dataset takes
                        #   and status of nulls
# Out:
#             University_name              Region  Founded_year  \
# 0   University of Cambridge     East of England          1209
# 1      University of Oxford  South East England          1096
# 2  University of St Andrews            Scotland          1413
#
#                                   Motto  UK_rank  World_rank  CWUR_score  \
# 0  From here, light and sacred draughts        1           4        94.1
# 1                  The Lord is my light        2           2        93.3
# 2                         Ever to excel        3          86        75.8
#
#    Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0                  6.5                        21750
# 1                  6.5                        21770
# 2                  6.5                        17040
#
#    PG_average_fees_(in_pounds)  ... Student_satisfaction Student_enrollment  \
# 0                        23187  ...               85.50%      20,000-24,999
# ...

# %% [markdown]
# <h5>At how many regions Univercities are present???   we can find out like this using </h5>**unique()**
#
#
# ---

# %%
universities.Region.unique()
# Out:
# array(['East of England', 'South East England', 'Scotland', 'London',
#        'East Midlands', 'North East England', 'North West England',
#        'West Midlands', 'South West England', 'Yorkshire and the Humber',
#        'Wales', 'Northern Ireland'], dtype=object)

# %%
#Distribution of univercities in regions
universities.Region.value_counts()
# Out:
# London                      22
# South East England          17
# Scotland                    14
# South West England          12
# North West England          11
# Yorkshire and the Humber    11
# East of England             10
# West Midlands               10
# Wales                        9
# East Midlands                7
# North East England           6
# Northern Ireland             2
# Name: Region, dtype: int64

# %% [markdown]
# **Let's Plot the above distribution:**

# %%
Region=universities.Region.value_counts() 
Region.plot(
           kind = 'bar',
           figsize = (10,10),
           title = "Distribution of Region"
           ) ;

# %% [markdown]
# # <h2>Task 1 Understand your numeric data How is it distributed.</h2>
#
#  Question 1: How is year distributed?</br>
#  Question 2: How is Uk_rank distributed?</br>
#  Question 3: Wow is World_rank distributed?</br>
#  Question 3: How is Cwur_Score distributed?</br>
#  Question 4: Use for loop to draw the distribution plots for the following
#             columns = ['CWUR_score',	'Minimum_IELTS_score',	'UG_average_fees_(in_pounds)',	'PG_average_fees_(in_pounds)']</br>

# %%
# 1 :How is year distributed?
sns.displot(universities.Founded_year)

# %%
#How is Uk_rank distributed?
#Wow is World_rank distributed?
#3: How is Cwur_Score distributed?
sns.displot(universities.UK_rank)
sns.displot(universities.World_rank)
sns.displot(universities.CWUR_score)

# %% [markdown]
# Using for loop to plot all at once

# %%
#4: Use for loop to draw the distribution plots for the following columns =
# ['CWUR_score', 'Minimum_IELTS_score', 'UG_average_fees_(in_pounds)', 'PG_average_fees_(in_pounds)']


columns = ['CWUR_score', 'Minimum_IELTS_score', 'UG_average_fees_(in_pounds)', 'PG_average_fees_(in_pounds)']
fig,ax = plt.subplots(2,2, figsize = (10,10))
ax = ax.flatten()
for i in range(len(columns)):
    sns.histplot(universities[columns[i]],ax = ax[i])

# %% [markdown]
# #Task 2:  Relationship of numeric to numeric variables
#   Using jointplots:
#           While jointplots may not show any linear relationship,           they can show by use of contour plots, given X, probable
#            Y through high density areas.
#
# Question 5:Show joint distribution of  'CWUR_Score' and 'Minimum IELTS_score?</br>
# Question 6:  Show joint distribution of 'UG_average_fees_(in_pounds)' and	PG_average_fees_(in_pounds)</br>
# Question 9: Show these plots as kernel density as also 'hex' as also
#             draw regression line

# %%
sns.jointplot(universities.CWUR_score,universities.Minimum_IELTS_score)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(universities.International_students,universities.Student_enrollment)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
 #Clearly two clusters are evident here
sns.jointplot(universities.CWUR_score,
              universities.Minimum_IELTS_score,
              kind = "kde"
              )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#
#Or plot hex plot
sns.jointplot(universities.CWUR_score,
              universities.Minimum_IELTS_score,
              kind = "hex"
              )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Add regression and kernel density fits:

sns.jointplot(universities.CWUR_score,
              universities.Minimum_IELTS_score,
              kind = "hex"
              )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Replationship plots

# %% [markdown]
# ## Relationship of a categorical to another categorical variable

# %%
# Note how seaborn uses estimator function
#     Barplots are grouped summaries, category wise
#     'estimator' is a summary function
#       For errobars, see this wikpedia on bootstrap statistics
#         https://en.wikipedia.org/wiki/Bootstrapping_(statistics)
#          Bootstrap statistics:
#          Repeatedly draw equal-sized samples of data (bootstrapping)
#           as in RandomForest & using these samples calculate 95% conf
#            interval, for example, np.sum and np.mean in the following cases

# %%
#Relationship of a numerical feature with a categorical feature
# Box Plot
num='UG_average_fees_(in_pounds)'
cat='Campus_setting'
df = universities

data = pd.concat([df[num], df[cat]], axis=1)
f, ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=cat, y=num, data=data)
fig.axis(ymin=0,ymax=25000)
print('\n')
cat='Region'
df = universities

data = pd.concat([df[num], df[cat]], axis=1)
f, ax = plt.subplots(figsize=(25,6))
fig = sns.boxplot(x=cat, y=num, data=data)
fig.axis(ymin=0,ymax=25000)
# Out:
# (-0.5, 2.5, 0.0, 25000.0)
# (-0.5, 11.5, 0.0, 25000.0)

# %%
#2.14 Correlation Heat Map
def getCorrHeatMap(dataFrame,figSize=[12,9]):
    corrmat = dataFrame.corr()
    f, ax = plt.subplots(figsize=(figSize[0], figSize[1]))
    sns.heatmap(corrmat, vmax=.8, square=True);

getCorrHeatMap(universities)

# %% [markdown]
# #  Investgation of missing values

# %%
#2.15 Investgation of missing values
def getMissingValuesInfo(df):
    total = df.isnull().sum().sort_values(ascending = False)
    percent = round(df.isnull().sum().sort_values(ascending = False)/len(df)*100, 2)
    temp = pd.concat([total, percent], axis = 1,keys= ['Total Missing Count', '% of Total Observations'])
    temp.index.name ='Feature Name'
    return temp.loc[(temp['Total Missing Count'] > 0)]

getMissingValuesInfo(universities)
# Out:
#                    Total Missing Count  % of Total Observations
# Feature Name
# CWUR_score                          47                    35.88
# Academic_Calender                   26                    19.85
# Campus_setting                      18                    13.74
# Motto                               17                    12.98

# %%
#  Visualizing missing values in a dataframe
#Visualizing missing counts
missing = universities.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
plt.subplots(figsize=(15,5))
missing.plot.bar()
plt.show()
# Out:
# (<Figure size 1080x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fd8596ce310>)
